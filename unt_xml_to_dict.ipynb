# %%
import xmltodict
 
#open the file
file = open("untl_sample.xml","r")

xml_content= file.read()
#print("XML content is:")
print(xml_content)

unt_xml = xmltodict.parse(xml_content)
#print(unt_xml['ns0:record'])
print(unt_xml['ns0:record']['ns0:metadata']['ns1:metadata'])
titles = unt_xml['ns0:record']['ns0:metadata']['ns1:metadata']['ns1:title']
print(titles['#text'])
subjects = unt_xml['ns0:record']['ns0:metadata']['ns1:metadata']['ns1:subject']
for subject in subjects:
    print(subject)
# Out:
# <ns0:record xmlns:ns0="http://www.openarchives.org/OAI/2.0/" xmlns:ns1="http://digital2.library.unt.edu/untl/">
# 	<ns0:header>
# 		<ns0:identifier>info:ark/67531/metapth1634350</ns0:identifier>
# 		<ns0:datestamp>2024-10-04T09:51:09Z</ns0:datestamp>
# 		<ns0:setSpec>partner:BRIT</ns0:setSpec>
# 		<ns0:setSpec>collection:SJCC</ns0:setSpec>
# 		<ns0:setSpec>access_rights:public</ns0:setSpec>
# 	</ns0:header>
# 	<ns0:metadata>
# 		<ns1:metadata>
# 			<ns1:title qualifier="officialtitle">[Echium pininana in the Canary Islands]</ns1:title>
# 			<ns1:creator qualifier="pht">
# 				<ns1:name>Carlquist, Sherwin John, 1930-2021</ns1:name>
# 				<ns1:type>per</ns1:type>
# 			</ns1:creator>
# 			<ns1:date qualifier="creation">1967</ns1:date>
# 			<ns1:language>zxx</ns1:language>
# 			<ns1:description qualifier="content">Photograph of an Echium pininana growing among other plants in the Canary Islands, Spain. The plant is tall and slender, growing straight upwards with longer leaves at the base and very small blue flowers near the top.</ns1:description>
# 			<ns1:description qualifier="physical">1 photograph : positive, col. ; 4 x 4 cm.</ns1:description>
# 			<ns1:subject qualifier="LCSH">Botany</ns1:subject>
# 			<ns1:subject qualifier="LCSH">Scientific expeditions</ns1:subject>
# 			<ns1:subject qualifier="LCSH">Biogeography</ns1:subject>
# 			<ns1:subject qualifier="UNTL-BS">Landscape and Nature - Plants</ns1:subject>
# 			<ns1:subject qualifier="AAT">color slides</ns1:subject>
# 			<ns1:subject qualifier="KWD">fieldwork</ns1:subject>
# 			<ns1:subject qualifier="KWD">field expeditions</ns1:subject>
# 			<ns1:subject qualifier="scientificName">Echium pininana</ns1:subject>
# 			<ns1:primarySource>1</ns1:primarySource>
# 			<ns1:coverage qualifier="date">1967</ns1:coverage>
# 			<ns1:coverage qualifier="timePeriod">mod-tim</ns1:coverage>
# 			<ns1:coverage qualifier="placeName">Spain - Canary Islands Autonomous Community</ns1:coverage>
# 			<ns1:citation qualifier="preferredCitation">Sherwin J. Carlquist Collection, Botanical Research Institute of Texas Library, Fort Worth Botanic Garden.</ns1:citation>
# 			<ns1:collection>SJCC</ns1:collection>
# 			<ns1:institution>BRIT</ns1:institution>
# 			<ns1:rights qualifier="license">https://creativecommons.org/licenses/by/4.0/</ns1:rights>
# 			<ns1:resourceType>image_photo</ns1:resourceType>
# 			<ns1:format>image</ns1:format>
# 			<ns1:identifier qualifier="itemURL">https://texashistory.unt.edu/ark:/67531/metapth1634350/</ns1:identifier>
# 			<ns1:identifier qualifier="LOCAL-CONT-NO">BRIT-A-AR003-002-01-039</ns1:identifier>
# 			<ns1:identifier qualifier="thumbnailURL">https://texashistory.unt.edu/ark:/67531/metapth1634350/small/</ns1:identifier>
# 			<ns1:identifier qualifier="ARK">ark:/67531/metapth1634350</ns1:identifier>
# 			<ns1:identifier qualifier="iiif-manifest">https://texashistory.unt.edu/ark:/67531/metapth1634350/manifest/</ns1:identifier>
# 			<ns1:note qualifier="display">Writing on slide box: &quot;Echium pininana
# Centaurea
# Canary&quot;</ns1:note>
# 			<ns1:meta qualifier="metadataCreator">htarver</ns1:meta>
# 			<ns1:meta qualifier="system">PTH</ns1:meta>
# 			<ns1:meta qualifier="ark">ark:/67531/metapth1634350</ns1:meta>
# 			<ns1:meta qualifier="metadataCreationDate">2024-01-22, 10:20:24</ns1:meta>
# 			<ns1:meta qualifier="metadataModifier">chudson</ns1:meta>
# 			<ns1:meta qualifier="metadataModificationDate">2024-10-04, 09:51:09</ns1:meta>
# 			<ns1:meta qualifier="hidden">False</ns1:meta>
# 		</ns1:metadata>
# 	</ns0:metadata>
# </ns0:record>
# {'ns1:title': {'@qualifier': 'officialtitle', '#text': '[Echium pininana in the Canary Islands]'}, 'ns1:creator': {'@qualifier': 'pht', 'ns1:name': 'Carlquist, Sherwin John, 1930-2021', 'ns1:type': 'per'}, 'ns1:date': {'@qualifier': 'creation', '#text': '1967'}, 'ns1:language': 'zxx', 'ns1:description': [{'@qualifier': 'content', '#text': 'Photograph of an Echium pininana growing among other plants in the Canary Islands, Spain. The plant is tall and slender, growing straight upwards with longer leaves at the base and very small blue flowers near the top.'}, {'@qualifier': 'physical', '#text': '1 photograph : positive, col. ; 4 x 4 cm.'}], 'ns1:subject': [{'@qualifier': 'LCSH', '#text': 'Botany'}, {'@qualifier': 'LCSH', '#text': 'Scientific expeditions'}, {'@qualifier': 'LCSH', '#text': 'Biogeography'}, {'@qualifier': 'UNTL-BS', '#text': 'Landscape and Nature - Plants'}, {'@qualifier': 'AAT', '#text': 'color slides'}, {'@qualifier': 'KWD', '#text': 'fieldwork'}, {'@qualifier': 'KWD', '#text': 'field expeditions'}, {'@qualifier': 'scientificName', '#text': 'Echium pininana'}], 'ns1:primarySource': '1', 'ns1:coverage': [{'@qualifier': 'date', '#text': '1967'}, {'@qualifier': 'timePeriod', '#text': 'mod-tim'}, {'@qualifier': 'placeName', '#text': 'Spain - Canary Islands Autonomous Community'}], 'ns1:citation': {'@qualifier': 'preferredCitation', '#text': 'Sherwin J. Carlquist Collection, Botanical Research Institute of Texas Library, Fort Worth Botanic Garden.'}, 'ns1:collection': 'SJCC', 'ns1:institution': 'BRIT', 'ns1:rights': {'@qualifier': 'license', '#text': 'https://creativecommons.org/licenses/by/4.0/'}, 'ns1:resourceType': 'image_photo', 'ns1:format': 'image', 'ns1:identifier': [{'@qualifier': 'itemURL', '#text': 'https://texashistory.unt.edu/ark:/67531/metapth1634350/'}, {'@qualifier': 'LOCAL-CONT-NO', '#text': 'BRIT-A-AR003-002-01-039'}, {'@qualifier': 'thumbnailURL', '#text': 'https://texashistory.unt.edu/ark:/67531/metapth1634350/small/'}, {'@qualifier': 'ARK', '#text': 'ark:/67531/metapth1634350'}, {'@qualifier': 'iiif-manifest', '#text': 'https://texashistory.unt.edu/ark:/67531/metapth1634350/manifest/'}], 'ns1:note': {'@qualifier': 'display', '#text': 'Writing on slide box: "Echium pininana\nCentaurea\nCanary"'}, 'ns1:meta': [{'@qualifier': 'metadataCreator', '#text': 'htarver'}, {'@qualifier': 'system', '#text': 'PTH'}, {'@qualifier': 'ark', '#text': 'ark:/67531/metapth1634350'}, {'@qualifier': 'metadataCreationDate', '#text': '2024-01-22, 10:20:24'}, {'@qualifier': 'metadataModifier', '#text': 'chudson'}, {'@qualifier': 'metadataModificationDate', '#text': '2024-10-04, 09:51:09'}, {'@qualifier': 'hidden', '#text': 'False'}]}
# [Echium pininana in the Canary Islands]
# {'@qualifier': 'LCSH', '#text': 'Botany'}
# {'@qualifier': 'LCSH', '#text': 'Scientific expeditions'}
# {'@qualifier': 'LCSH', '#text': 'Biogeography'}
# {'@qualifier': 'UNTL-BS', '#text': 'Landscape and Nature - Plants'}
# {'@qualifier': 'AAT', '#text': 'color slides'}
# {'@qualifier': 'KWD', '#text': 'fieldwork'}
# {'@qualifier': 'KWD', '#text': 'field expeditions'}
# {'@qualifier': 'scientificName', '#text': 'Echium pininana'}
